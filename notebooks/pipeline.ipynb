# %%
from pymongo.mongo_client import MongoClient


user = {'username': 'othiagomares', 'senha': 'Ferreira13'}
uri = f"mongodb+srv://{user['username']}:{user['senha']}@cluster-pipeline.jj6tyuo.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client["db_produtos"]
colecao = db["produtos"]

# %%
client.list_database_names() # Para a base de dados seja criada, precisa ter pelo menos um dado

product = {
    "Produto": "computador",
    "quantidade": 99
}

colecao.insert_one(product)
# Out:
# InsertOneResult(ObjectId('659f308c8027d296d4933981'), acknowledged=True)

# %%
colecao.find_one()
# Out:
# {'_id': ObjectId('659f308c8027d296d4933981'),
#  'Produto': 'computador',
#  'quantidade': 99}

# %%
client.list_database_names()
# Out:
# ['db_produtos', 'sample_mflix', 'admin', 'local']

# %%
import requests

response = requests.get('https://labdados.com/produtos')
dados = response.json()
dados
# Out:
# [{'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 92.45,
#   'Frete': 5.6096965236,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 43.84,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 87.18,
#   'Frete': 2.2265117938,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
# ...

# %%
len(dados)
# Out:
# 9435

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('659f322b8027d296d4933982'), ObjectId('659f322b8027d296d4933983'), ObjectId('659f322b8027d296d4933984'), ObjectId('659f322b8027d296d4933985'), ObjectId('659f322b8027d296d4933986'), ObjectId('659f322b8027d296d4933987'), ObjectId('659f322b8027d296d4933988'), ObjectId('659f322b8027d296d4933989'), ObjectId('659f322b8027d296d493398a'), ObjectId('659f322b8027d296d493398b'), ObjectId('659f322b8027d296d493398c'), ObjectId('659f322b8027d296d493398d'), ObjectId('659f322b8027d296d493398e'), ObjectId('659f322b8027d296d493398f'), ObjectId('659f322b8027d296d4933990'), ObjectId('659f322b8027d296d4933991'), ObjectId('659f322b8027d296d4933992'), ObjectId('659f322b8027d296d4933993'), ObjectId('659f322b8027d296d4933994'), ObjectId('659f322b8027d296d4933995'), ObjectId('659f322b8027d296d4933996'), ObjectId('659f322b8027d296d4933997'), ObjectId('659f322b8027d296d4933998'), ObjectId('659f322b8027d296d4933999'), ObjectId('659f322b8027d296d493399a'), ObjectId('659f322b8027d296d493
# ...

# %%
colecao.count_documents({})
# Out:
# 9436

# %%
client.close()
